# %% [markdown]
# # Exam 2
#
# ## 1. Introduction
# The companion Google Form for this exam includes a set of questions that you can only answer by writing code. That code must be entered into this notebook.
#
# Some requirements:
# 1. This notebook must clearly **show all the work necessary to answer each question** in the Google Form.
# 1. **Your code must unambiguously show that you have answered each question**.  For questions where you are unable to determine the answer using code, include descriptive text explaining what you believe to be the answer, and any reason you are unable to show it in the code.
# 1. All code in this notebook must be **well-documented using Markdown**.  Indicate each question you are answering and clearly describe what each block of code is doing.  Your ability to write well-formatted Markdown that clearly explains your work will be factored into your grade.
# 1. Once you have determined the answer to each question, remember to **enter the answer for each question into the Google Form** - we need both this notebook and the completed Google Form in order to grade your work.
# 1. Save this notebook and **push this repository to GitHub when done**.

# %%
# given code... do not modify
# %matplotlib inline
import numpy as np
import pandas as pd
from IPython.display import Markdown as md

df = pd.read_csv('./data/Production_Livestock_E_All_Data/Production_Livestock_E_All_Data.csv')

# %% [markdown]
# ## 2. Data source and definitions
# The data used in this notebook comes from the [Food and Agriculture Organizaion of the United Nations](http://www.fao.org/faostat/en/#data/QA) and represents counts of livestock produced in various areas around the world for every year from 1961-2019.
#
# Several fields in this data may benefit from a bit of explanation.  You are welcome to review the Definitions of the fields by clicking the green `Definitions and standards` button present on website linked above.
# - `Area` represents a country or region, e.g. `"Austria"` and `"Western Europe"`
# - `Item` represents the specific type or a group of livestock, e.g. `"Sheep"` and `"Sheep and Goats"`
# - `Unit` indicates whether the numbers in the yearly count fields represent counts of single animals (`"Head"` or `"No"`), 1000s of animals (`"1000 Head"`).
# - yearly counts are in the fields named `Yxxxx`, where `xxxx` is a year, e.g. `Y1961` for the counts of a given animal in a given area in the year 1961.
# - the field names following the format, `YxxxxF` indicate whether the count for a given year is an estimate or an actual count.  Estimates are indicated with an `F` or `Im` in this field, while actual counts have no value in this field.

# %% [markdown]
# ## 3. Data sample

# %%
# given code... do not modify
df.sample(5)
# Out:
#       Area Code      Area  Item Code             Item  Element Code Element  \
# 1745        166    Panama       1034             Pigs          5111  Stocks
# 967          84    Greece       1749  Sheep and Goats          5111  Stocks
# 791         209  Eswatini       1110            Mules          5111  Stocks
# 1657        158     Niger       1016            Goats          5111  Stocks
# 845          67   Finland       1096           Horses          5111  Stocks
#
#       Unit       Y1961 Y1961F       Y1962  ...       Y2015  Y2015F  \
# 1745  Head    222289.0    NaN    204000.0  ...    365000.0     NaN
# 967   Head  14417000.0      A  13565000.0  ...  12874296.0       A
# 791   Head       509.0    NaN       788.0  ...       106.0      Im
# 1657  Head   4940000.0    NaN   5200000.0  ...  15478902.0     NaN
# 845   Head    234710.0    NaN    227500.0  ...     74200.0     NaN
#
#            Y2016  Y2016F       Y2017  Y2017F       Y2018  Y2018F       Y2019  \
# 1745    389000.0     NaN    400700.0     NaN    369200.0     NaN    354500.0
# 967   12655739.0       A  12826025.0       A  12055000.0       A  12007000.0
# 791        108.0      Im       108.0      Im       109.0      Im       111.0
# 1657  16098058.0     NaN  16741979.0     NaN  17411658.0     NaN  18108124.0
# 845      74200.0     NaN     74400.0     NaN     74400.0     NaN         NaN
#
#       Y2019F
# 1745     NaN
# 967        A
# 791       Im
# 1657     NaN
# 845      NaN
#
# [5 rows x 125 columns]

# %% [markdown]
# # Your Work
# Add all the code and documentation you need to answer the exam questions below this block. Keep your notebook organized so it is obvious which question you are answering (no need to repeat the entire question) and the order of answers follows the order of the questions in the exam.
#
# The following section will contain code you need to write to answer questions from the Pandas section of the Google form.

# %% [markdown]
# ## Question 1

# %% [markdown]
# For this question I simply created new dataframe that includes only values that satisfy my condition. My condition is that "Area" column is China, so that I exclude other Areas from my dataframe. After that I had to limit my dataframe to a Series where only to 2017 Year production which helped me to calculate the sum of livestock animals that were produced in China in the year 2017

# %%
df_china = df[df['Area'] == "China"]
df_china_2017 = df_china['Y2017']
df_china_2017.sum()
# Out:
# 1258085411.0

# %% [markdown]
# ## Question 2

# %% [markdown]
# In order to answer this question, firstly, I created new dataframe which only had values satisfying condtion 'Area' == 'United States of America'. Then I limited this dataframe only to Item 'Pigs'. Added new variable "difference" which is a Series of size one giving me the difference between number of Pigs in USA between 2019 and 1961. Then using the assign() function I added new column "Difference_2019_1961_pigs" to the df_usa_pigs dataframe to get the answer and data representation.

# %%
df_usa = df[df['Area'] == "United States of America"]
df_usa_pigs = df_usa[df_usa["Item"] == "Pigs"]
difference = df_usa_pigs["Y2019"] - df_usa_pigs["Y1961"]
df_usa_pigs = df_usa_pigs.assign(Difference_2019_1961_pigs = difference)
df_usa_pigs[["Area", "Item", "Difference_2019_1961_pigs"]]
# Out:
#                           Area  Item  Difference_2019_1961_pigs
# 2451  United States of America  Pigs                 23097600.0

# %% [markdown]
# ## Question 3

# %% [markdown]
# The answer for this question is "None of the above". The code below is the right code.

# %%
df_usa[["Item", "Y2019"]]
# Out:
#                       Item       Y2019
# 2443                 Asses     51971.0
# 2444              Beehives   2812000.0
# 2445                Cattle  94804700.0
# 2446              Chickens   1972256.0
# 2447                 Ducks      7365.0
# 2448                 Goats   2622000.0
# 2449                Horses  10702799.0
# 2450                 Mules         NaN
# 2451                  Pigs  78657600.0
# 2452                 Sheep   5230000.0
# 2453               Turkeys    229000.0
# 2454  Cattle and Buffaloes  94804700.0
# 2455         Poultry Birds   2208621.0
# 2456       Sheep and Goats   7852000.0

# %% [markdown]
# ## Question 4

# %% [markdown]
# In order to create a pandas DataFrame that contains the data from only those rows related to the USA, I used condition ['Area'] == 'United States of America' and output are rows that satisfy that condition. This new dataframe I called df_usa

# %%
df_usa = df[df['Area'] == 'United States of America']
df_usa
# Out:
#       Area Code                      Area  Item Code                  Item  \
# 2443        231  United States of America       1107                 Asses
# 2444        231  United States of America       1181              Beehives
# 2445        231  United States of America        866                Cattle
# 2446        231  United States of America       1057              Chickens
# 2447        231  United States of America       1068                 Ducks
# 2448        231  United States of America       1016                 Goats
# 2449        231  United States of America       1096                Horses
# 2450        231  United States of America       1110                 Mules
# 2451        231  United States of America       1034                  Pigs
# 2452        231  United States of America        976                 Sheep
# 2453        231  United States of America       1079               Turkeys
# 2454        231  United States of America       1746  Cattle and Buffaloes
# 2455        231  United States of America       2029         Poultry Birds
# 2456        231  United States of America       1749       Sheep and Goats
#
#       Element Code Element       Unit       Y1961 Y1961F        Y1962  ...  \
# 2443          5111  Stocks       Head     15000.0      F      15000.0  ...
# 2444          5114  Stocks         No   5514000.0    NaN    5506000.0  ...
# 2445          5111  Stocks       Head  97700000.0    NaN  100369008.0  ...
# 2446          5112  Stocks  1000 Head    751000.0      F     782000.0  ...
# 2447          5112  Stocks  1000 Head      3500.0      F       3400.0  ...
# 2448          5111  Stocks       Head   3473000.0    NaN    3647000.0  ...
# 2449          5111  Stocks       Head   2367000.0      F    2130000.0  ...
# 2450          5111  Stocks       Head     20000.0      F      20000.0  ...
# 2451          5111  Stocks       Head  55560000.0    NaN   61837008.0  ...
# 2452          5111  Stocks       Head  32725008.0    NaN   30969008.0  ...
# 2453          5112  Stocks  1000 Head    107496.0    NaN      91837.0  ...
# 2454          5111  Stocks       Head  97700000.0      A  100369008.0  ...
# 2455          5112  Stocks  1000 Head    861996.0      A     877237.0  ...
# 2456          5111  Stocks       Head  36198008.0      A   34616008.0  ...
#
#            Y2015  Y2015F       Y2016  Y2016F       Y2017  Y2017F       Y2018  \
# 2443     51986.0      Im     51976.0      Im     51974.0      Im     51972.0
# 2444   2660000.0     NaN   2775000.0     NaN   2684000.0     NaN   2828000.0
# 2445  89143000.0     NaN  91888000.0     NaN  93624600.0     NaN  94298000.0
# 2446   1998146.0      Im   1972264.0      Im   1971919.0      Im   1972088.0
# 2447      7568.0      Im      7337.0      Im      7278.0      Im      7327.0
# 2448   2650000.0     NaN   2615000.0     NaN   2627000.0     NaN   2639000.0
# 2449  10267608.0      Im  10528668.0      Im  10557429.0      Im  10630350.0
# 2450         0.0       F         0.0       F         0.0       F         NaN
# 2451  68919300.0     NaN  71345400.0     NaN  73144900.0     NaN  75070200.0
# 2452   5280000.0     NaN   5295000.0     NaN   5270000.0     NaN   5265000.0
# 2453    233100.0     NaN    244000.0     NaN    245200.0     NaN    238000.0
# 2454  89143000.0       A  91888000.0       A  93624600.0       A  94298000.0
# 2455   2238814.0       A   2223601.0       A   2224397.0       A   2217415.0
# 2456   7930000.0       A   7910000.0       A   7897000.0       A   7904000.0
#
#       Y2018F       Y2019  Y2019F
# 2443      Im     51971.0      Im
# 2444     NaN   2812000.0     NaN
# 2445     NaN  94804700.0     NaN
# 2446      Im   1972256.0      Im
# 2447      Im      7365.0      Im
# 2448     NaN   2622000.0     NaN
# 2449      Im  10702799.0      Im
# 2450       M         NaN       M
# 2451     NaN  78657600.0     NaN
# 2452     NaN   5230000.0     NaN
# 2453     NaN    229000.0     NaN
# 2454       A  94804700.0       A
# 2455       A   2208621.0       A
# 2456       A   7852000.0       A
#
# [14 rows x 125 columns]

# %% [markdown]
# ## Question 5

# %% [markdown]
# In order to check data type of column Yxxxx, I used dtypes function which gave me the answer "float64".

# %%
df['Y1961'].dtypes
# Out:
# dtype('float64')

# %% [markdown]
# ## Question 6

# %% [markdown]
# Simply function del, deletes the whole column named 'Area Code' from the given dataframe (in this case df_usa). As a result the number of columns decreased by one. Before we had 125 columns, after del function we have 124 columns.

# %%
df_usa = df[df['Area'] == "United States of America"]
del df_usa[ 'Area Code' ]
df_usa
# Out:
#                           Area  Item Code                  Item  Element Code  \
# 2443  United States of America       1107                 Asses          5111
# 2444  United States of America       1181              Beehives          5114
# 2445  United States of America        866                Cattle          5111
# 2446  United States of America       1057              Chickens          5112
# 2447  United States of America       1068                 Ducks          5112
# 2448  United States of America       1016                 Goats          5111
# 2449  United States of America       1096                Horses          5111
# 2450  United States of America       1110                 Mules          5111
# 2451  United States of America       1034                  Pigs          5111
# 2452  United States of America        976                 Sheep          5111
# 2453  United States of America       1079               Turkeys          5112
# 2454  United States of America       1746  Cattle and Buffaloes          5111
# 2455  United States of America       2029         Poultry Birds          5112
# 2456  United States of America       1749       Sheep and Goats          5111
#
#      Element       Unit       Y1961 Y1961F        Y1962 Y1962F  ...  \
# 2443  Stocks       Head     15000.0      F      15000.0      F  ...
# 2444  Stocks         No   5514000.0    NaN    5506000.0    NaN  ...
# 2445  Stocks       Head  97700000.0    NaN  100369008.0    NaN  ...
# 2446  Stocks  1000 Head    751000.0      F     782000.0      F  ...
# 2447  Stocks  1000 Head      3500.0      F       3400.0      F  ...
# 2448  Stocks       Head   3473000.0    NaN    3647000.0    NaN  ...
# 2449  Stocks       Head   2367000.0      F    2130000.0      F  ...
# 2450  Stocks       Head     20000.0      F      20000.0      F  ...
# 2451  Stocks       Head  55560000.0    NaN   61837008.0    NaN  ...
# 2452  Stocks       Head  32725008.0    NaN   30969008.0    NaN  ...
# 2453  Stocks  1000 Head    107496.0    NaN      91837.0    NaN  ...
# 2454  Stocks       Head  97700000.0      A  100369008.0      A  ...
# 2455  Stocks  1000 Head    861996.0      A     877237.0      A  ...
# 2456  Stocks       Head  36198008.0      A   34616008.0      A  ...
#
#            Y2015 Y2015F       Y2016 Y2016F       Y2017 Y2017F       Y2018  \
# 2443     51986.0     Im     51976.0     Im     51974.0     Im     51972.0
# 2444   2660000.0    NaN   2775000.0    NaN   2684000.0    NaN   2828000.0
# 2445  89143000.0    NaN  91888000.0    NaN  93624600.0    NaN  94298000.0
# 2446   1998146.0     Im   1972264.0     Im   1971919.0     Im   1972088.0
# 2447      7568.0     Im      7337.0     Im      7278.0     Im      7327.0
# 2448   2650000.0    NaN   2615000.0    NaN   2627000.0    NaN   2639000.0
# 2449  10267608.0     Im  10528668.0     Im  10557429.0     Im  10630350.0
# 2450         0.0      F         0.0      F         0.0      F         NaN
# 2451  68919300.0    NaN  71345400.0    NaN  73144900.0    NaN  75070200.0
# 2452   5280000.0    NaN   5295000.0    NaN   5270000.0    NaN   5265000.0
# 2453    233100.0    NaN    244000.0    NaN    245200.0    NaN    238000.0
# 2454  89143000.0      A  91888000.0      A  93624600.0      A  94298000.0
# 2455   2238814.0      A   2223601.0      A   2224397.0      A   2217415.0
# 2456   7930000.0      A   7910000.0      A   7897000.0      A   7904000.0
#
#      Y2018F       Y2019 Y2019F
# 2443     Im     51971.0     Im
# 2444    NaN   2812000.0    NaN
# 2445    NaN  94804700.0    NaN
# 2446     Im   1972256.0     Im
# 2447     Im      7365.0     Im
# 2448    NaN   2622000.0    NaN
# 2449     Im  10702799.0     Im
# 2450      M         NaN      M
# 2451    NaN  78657600.0    NaN
# 2452    NaN   5230000.0    NaN
# 2453    NaN    229000.0    NaN
# 2454      A  94804700.0      A
# 2455      A   2208621.0      A
# 2456      A   7852000.0      A
#
# [14 rows x 124 columns]
